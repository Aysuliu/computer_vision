# %% [markdown]
# <a href="https://colab.research.google.com/github/Aysuliu/computer_vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
downloader.download("kebab shashlik food",
                    limit=100,
                    output_dir='/content/kebab_images',
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
)
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.licious.in/blog/wp-content/uploads/2020/12/Turkish-Kebabs-min.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://wallpaperaccess.com/full/10831705.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/f9/4d/9b/f94d9bc8f56d3d0302fc7e727947eb0d.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://www.thespruceeats.com/thmb/47Y9vapBkwe_98TIiueYFB3OObc=/2059x2059/filters:no_upscale():max_bytes(150000):strip_icc()/aIMG_0756fsq-5aebd1ddc0647100364ee63a.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://img.freepik.com/premium-photo/doner-kebab-doner-kebap-fast-food-meal-flatbread-with-fries-wooden-board_770123-5.jpg?w=2000
# [%] File Downloaded!
#
# ...

# %%
import os, shutil
source_dir = '/content/kebab_images/kebab shashlik food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'
os.makedirs(target_dir, exist_ok=True)
for file_name in os.listdir(source_dir):
    src_file = os.path.join(source_dir, file_name)
    dst_file = os.path.join(target_dir, file_name)
    shutil.move(src_file, dst_file)

# %%
# !rm -rf /content/drive/MyDrive/food101_dataset/ramen
# !rm -rf /content/drive/MyDrive/food101_dataset/steak

# %%
# !rm -rf /content/drive/MyDrive/food101_dataset/pilaf

# %%
import shutil
import os

# Remove previously downloaded images to ensure a clean slate
if os.path.exists('/content/pilaf_images'):
    shutil.rmtree('/content/pilaf_images')

# %%
downloader.download("pilaf plov food",
                    limit=100,
                    output_dir='/content/pilaf_images',
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
)
# Out:
# [%] Downloading Images to /content/pilaf_images/pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 25 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://ejemplo.com.ar/wp-content/uploads/2025/09/ejemplos-practicos-de-referencias-vancouver-para-tus-trabajos-academicos-1536x864.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://retos.educatic.unam.mx/pluginfile.php/69/mod_page/content/102/apa01.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://d20ohkaloyme4g.cloudfront.net/img/document_thumbnails/34cb5b2eca25efa76f5758d63964ecc4/thumb_1200_1553.png
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://normasapa.in/wp-content/uploads/2022/05/citas-normas-apa.png
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://0.academia-photos.com/attachment_thumbnails/58361745/mini_magick20190208-18693-1z12bd5.png?1549663922
# [%] File Downloaded!
#
# ...

# %%
import os, shutil
source_dir = '/content/pilaf_images/pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'
os.makedirs(target_dir, exist_ok=True)
for file_name in os.listdir(source_dir):
    src_file = os.path.join(source_dir, file_name)
    dst_file = os.path.join(target_dir, file_name)
    shutil.move(src_file, dst_file)
