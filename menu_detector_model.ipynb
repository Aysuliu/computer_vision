# %% [markdown]
# <a href="https://colab.research.google.com/github/Aysuliu/computer_vision/blob/main/menu_detector_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defien dataset path

DATASET_PATH = '/content/drive/MyDrive/food101_dataset'

CUSTOM_CLASS_MAPPING = {
    'hamburger': 'hamburger',
    'hot_dog': 'hot_dog',
    'chocolate_cake': 'dessert', #label grouping | class consolidation
    'cheesecake': 'dessert',     #label grouping | class consolidation
    'kebab': 'kebab',
    'pizza': 'pizza'
}

CLASSES = ['hamburger','hot_dog','dessert','kebab', 'pizza']
CLASS_TO_IDX = {cls: i for i, cls in enumerate(CLASSES)}
NUM_CLASSES = len(CLASSES)
print(CLASS_TO_IDX)
# Out:
# {'hamburger': 0, 'hot_dog': 1, 'dessert': 2, 'kebab': 3, 'pizza': 4}
